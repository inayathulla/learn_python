# %% [markdown]
# # Input - Output

# %% [markdown]
# ### Output

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
a = 100
b = 'marks'
print(a, b)
# Out:
# 100 marks

# %%
print(a)
print(b)
# Out:
# 100
# marks

# %%
print(a, end=" ")
print(b)
# Out:
# 100 marks

# %%
print(a, b, sep="-")
# Out:
# 100-marks

# %% [markdown]
# ### Input

# %%
greeting = input()
print(greeting)

# %%
greeting = input('Enter you name: ')
print('Hello', greeting)

# %%
x = input('Enter value of X:')
y = input('Enter value of Y:')

print(x + y)

# %%
x = int(input('Enter value of X:'))
y = int(input('Enter value of Y:'))
print(x + y)
